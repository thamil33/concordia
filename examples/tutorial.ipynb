# %% [markdown]
# This notebook is a basic tutorial that demonstrates how to configure a simulation using Concordia.

# %%
# @title Imports

import numpy as np
from IPython import display

import sentence_transformers

from concordia.language_model.model_client_initialization import ModelClient

from concordia.prefabs.simulation import generic as simulation

import concordia.prefabs.entity as entity_prefabs
import concordia.prefabs.game_master as game_master_prefabs

from concordia.type_checks import prefab as prefab_lib
from concordia.utils import helper_functions
# Out:
# c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
# Initialize the client
client = ModelClient()
model = client.model
embedder = client.embedder
# Out:
# Initializing model for provider: lmstudio

# %%
test = model.sample_text(
    'Answer with a single statement: What is the capital of France?')
print(test)
# Out:
# The capital of France is Paris.

# %%
# @title Load prefabs from packages to make the specific palette to use here.

prefabs = {
    **helper_functions.get_package_classes(entity_prefabs),
    **helper_functions.get_package_classes(game_master_prefabs),
}

# %%
#@title Print menu of prefabs

display.display(
    display.Markdown(helper_functions.print_pretty_prefabs(prefabs)))

# %%
# @title Configure instances.

instances = [
    prefab_lib.InstanceConfig(
        prefab='basic__Entity',
        role=prefab_lib.Role.ENTITY,
        params={
            'name': 'Oliver Cromwell',
            'goal': 'become lord protector',
        },
    ),
    prefab_lib.InstanceConfig(
        prefab='basic__Entity',
        role=prefab_lib.Role.ENTITY,
        params={
            'name': 'King Charles I',
            'goal': 'avoid execution for treason',
        },
    ),
    prefab_lib.InstanceConfig(
        prefab='generic__GameMaster',
        role=prefab_lib.Role.GAME_MASTER,
        params={
            'name': 'default rules',
            # Comma-separated list of thought chain steps.
            'extra_event_resolution_steps': '',
        },
    ),
    prefab_lib.InstanceConfig(
        prefab='formative_memories_initializer__GameMaster',
        role=prefab_lib.Role.INITIALIZER,
        params={
            'name': 'initial setup rules',
            'next_game_master_name': 'default rules',
            'shared_memories': [
                'The king was captured by Parliamentary forces in 1646.',
                'Charles I was tried for treason and found guilty.',
            ],
        },
    ),
]

# %%
config = prefab_lib.Config(
    default_premise=f'Today is January 29, 1649.',
    default_max_steps=5,
    prefabs=prefabs,
    instances=instances,
)

# %% [markdown]
# # The simulation

# %%
# @title Initialize the simulation
runnable_simulation = simulation.Simulation(
    config=config,
    model=model,
    embedder=embedder,
)

# %%
# @title Run the simulation
raw_log = []
results_log = runnable_simulation.play(max_steps=4,
                                       raw_log=raw_log)
# Out:
# Terminate? No
# ERROR:absl:Error in task King Charles I
# Traceback (most recent call last):
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_transports\default.py", line 101, in map_httpcore_exceptions
#     yield
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_transports\default.py", line 250, in handle_request
#     resp = self._pool.handle_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\connection_pool.py", line 256, in handle_request
#     raise exc from None
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\connection_pool.py", line 236, in handle_request
#     response = connection.handle_request(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\connection.py", line 103, in handle_request
#     return self._connection.handle_request(request)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\http11.py", line 136, in handle_request
#     raise exc
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\http11.py", line 106, in handle_request
#     ) = self._receive_response_headers(**kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\http11.py", line 177, in _receive_response_headers
#     event = self._receive_event(timeout=timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\http11.py", line 217, in _receive_event
#     data = self._network_stream.read(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_backends\sync.py", line 126, in read
#     with map_exceptions(exc_map):
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\contextlib.py", line 158, in __exit__
#     self.gen.throw(value)
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_exceptions.py", line 14, in map_exceptions
#     raise to_exc(exc) from exc
# httpcore.ReadTimeout: timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\openai\_base_client.py", line 972, in request
#     response = self._client.send(
#                ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_client.py", line 914, in send
#     response = self._send_handling_auth(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_client.py", line 942, in _send_handling_auth
#     response = self._send_handling_redirects(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_client.py", line 979, in _send_handling_redirects
#     response = self._send_single_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_client.py", line 1014, in _send_single_request
#     response = transport.handle_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_transports\default.py", line 249, in handle_request
#     with map_httpcore_exceptions():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\contextlib.py", line 158, in __exit__
#     self.gen.throw(value)
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_transports\default.py", line 118, in map_httpcore_exceptions
#     raise mapped_exc(message) from exc
# httpx.ReadTimeout: timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\tyler\Documents\dev\concordia\concordia_orgin\concordia\concordia\utils\concurrency.py", line 60, in _run_task
#     return fn()
#            ^^^^
#   File "C:\Users\tyler\Documents\dev\concordia\concordia_orgin\concordia\concordia\components\game_master\next_game_master.py", line 263, in _process_player
#     episodes = self.generate_backstory_episodes(player_name)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\tyler\Documents\dev\concordia\concordia_orgin\concordia\concordia\components\game_master\next_game_master.py", line 333, in generate_backstory_episodes
#     backstory = prompt.open_question(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\tyler\Documents\dev\concordia\concordia_orgin\concordia\concordia\document\interactive_document.py", line 176, in open_question
#     response = self._model.sample_text(
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\tyler\Documents\dev\concordia\concordia_orgin\concordia\concordia\language_model\base_oai_compatible.py", line 76, in sample_text
#     response = self._client.chat.completions.create(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\openai\_utils\_utils.py", line 287, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\openai\resources\chat\completions\completions.py", line 1087, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\openai\_base_client.py", line 1249, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\openai\_base_client.py", line 990, in request
#     raise APITimeoutError(request=request) from err
# openai.APITimeoutError: Request timed out.
# ERROR:absl:Error in task 2660061139392
# Traceback (most recent call last):
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_transports\default.py", line 101, in map_httpcore_exceptions
#     yield
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_transports\default.py", line 250, in handle_request
#     resp = self._pool.handle_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\connection_pool.py", line 256, in handle_request
#     raise exc from None
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\connection_pool.py", line 236, in handle_request
#     response = connection.handle_request(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\connection.py", line 103, in handle_request
#     return self._connection.handle_request(request)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\http11.py", line 136, in handle_request
#     raise exc
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\http11.py", line 106, in handle_request
#     ) = self._receive_response_headers(**kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\http11.py", line 177, in _receive_response_headers
#     event = self._receive_event(timeout=timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\http11.py", line 217, in _receive_event
#     data = self._network_stream.read(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_backends\sync.py", line 126, in read
#     with map_exceptions(exc_map):
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\contextlib.py", line 158, in __exit__
#     self.gen.throw(value)
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_exceptions.py", line 14, in map_exceptions
#     raise to_exc(exc) from exc
# httpcore.ReadTimeout: timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\openai\_base_client.py", line 972, in request
#     response = self._client.send(
#                ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_client.py", line 914, in send
#     response = self._send_handling_auth(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_client.py", line 942, in _send_handling_auth
#     response = self._send_handling_redirects(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_client.py", line 979, in _send_handling_redirects
#     response = self._send_single_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_client.py", line 1014, in _send_single_request
#     response = transport.handle_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_transports\default.py", line 249, in handle_request
#     with map_httpcore_exceptions():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\contextlib.py", line 158, in __exit__
#     self.gen.throw(value)
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_transports\default.py", line 118, in map_httpcore_exceptions
#     raise mapped_exc(message) from exc
# httpx.ReadTimeout: timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\tyler\Documents\dev\concordia\concordia_orgin\concordia\concordia\utils\concurrency.py", line 60, in _run_task
#     return fn()
#            ^^^^
#   File "C:\Users\tyler\Documents\dev\concordia\concordia_orgin\concordia\concordia\components\game_master\next_game_master.py", line 281, in pre_act
#     concurrency.run_tasks(tasks)
#   File "C:\Users\tyler\Documents\dev\concordia\concordia_orgin\concordia\concordia\utils\concurrency.py", line 139, in run_tasks
#     key: future.result()
#          ^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\concurrent\futures\_base.py", line 449, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\concurrent\futures\_base.py", line 401, in __get_result
#     raise self._exception
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\concurrent\futures\thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\tyler\Documents\dev\concordia\concordia_orgin\concordia\concordia\utils\concurrency.py", line 60, in _run_task
#     return fn()
#            ^^^^
#   File "C:\Users\tyler\Documents\dev\concordia\concordia_orgin\concordia\concordia\components\game_master\next_game_master.py", line 263, in _process_player
#     episodes = self.generate_backstory_episodes(player_name)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\tyler\Documents\dev\concordia\concordia_orgin\concordia\concordia\components\game_master\next_game_master.py", line 333, in generate_backstory_episodes
#     backstory = prompt.open_question(
#                 ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\tyler\Documents\dev\concordia\concordia_orgin\concordia\concordia\document\interactive_document.py", line 176, in open_question
#     response = self._model.sample_text(
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\tyler\Documents\dev\concordia\concordia_orgin\concordia\concordia\language_model\base_oai_compatible.py", line 76, in sample_text
#     response = self._client.chat.completions.create(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\openai\_utils\_utils.py", line 287, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\openai\resources\chat\completions\completions.py", line 1087, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\openai\_base_client.py", line 1249, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\openai\_base_client.py", line 990, in request
#     raise APITimeoutError(request=request) from err
# openai.APITimeoutError: Request timed out.
# ---------------------------------------------------------------------------
# ReadTimeout                               Traceback (most recent call last)
# File c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     135         self._response_closed()
# --> 136 raise exc
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     125 exc_map: ExceptionMapping = {socket.timeout: ReadTimeout, OSError: ReadError}
# --> 126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ReadTimeout: timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeout                               Traceback (most recent call last)
# File c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\openai\_base_client.py:972, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     971 try:
# --> 972     response = self._client.send(
#     973         request,
#     974         stream=stream or self._should_stream_response_body(request=request),
#     975         **kwargs,
#     976     )
#     977 except httpx.TimeoutException as err:
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_transports\default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_transports\default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ReadTimeout: timed out
#
# The above exception was the direct cause of the following exception:
#
# APITimeoutError                           Traceback (most recent call last)
# Cell In[13], line 3
#       1 # @title Run the simulation
#       2 raw_log = []
# ----> 3 results_log = runnable_simulation.play(max_steps=4,
#       4                                        raw_log=raw_log)
#
# File ~\Documents\dev\concordia\concordia_orgin\concordia\concordia\prefabs\simulation\generic.py:267, in Simulation.play(self, premise, max_steps, raw_log, get_state_callback, checkpoint_path)
#     260 other_gms = [
#     261     gm
#     262     for gm in self.game_masters
#     263     if self._entity_to_prefab_config[gm.name].role == Role.GAME_MASTER
#     264 ]
#     265 sorted_game_masters = initializers + other_gms
# --> 267 self._engine.run_loop(
#     268     game_masters=sorted_game_masters,
#     269     entities=self.entities,
#     270     premise=premise,
#     271     max_steps=max_steps,
#     272     verbose=True,
#     273     log=raw_log,
#     274     checkpoint_callback=checkpoint_callback,
#     275 )
#     277 player_logs = []
#     278 player_log_names = []
#
# File ~\Documents\dev\concordia\concordia_orgin\concordia\concordia\environment\engines\sequential.py:230, in Sequential.run_loop(self, game_masters, entities, premise, max_steps, verbose, log, checkpoint_callback)
#     227   assert hasattr(game_master, 'get_last_log')  # Assertion for pytype
#     228   log_entry['terminate'] = game_master.get_last_log()
# --> 230 game_master = self.next_game_master(game_master, game_masters, verbose)
#     231 if log is not None and hasattr(game_master, 'get_last_log'):
#     232   assert hasattr(game_master, 'get_last_log')  # Assertion for pytype
#
# File ~\Documents\dev\concordia\concordia_orgin\concordia\concordia\environment\engines\sequential.py:188, in Sequential.next_game_master(self, game_master, game_masters, verbose)
#     184   return game_masters[0]
#     185 game_masters_by_name = {
#     186     game_master_.name: game_master_ for game_master_ in game_masters
#     187 }
# --> 188 next_game_master_name = game_master.act(
#     189     action_spec=entity_lib.ActionSpec(
#     190         call_to_action=self._call_to_next_game_master,
#     191         output_type=entity_lib.OutputType.NEXT_GAME_MASTER,
#     192         options=tuple(game_masters_by_name.keys()),
#     193     )
#     194 )
#     195 if verbose:
#     196   print(termcolor.colored(
#     197       f'Game master: {next_game_master_name}', _PRINT_COLOR))
#
# File ~\Documents\dev\concordia\concordia_orgin\concordia\concordia\agents\entity_agent.py:169, in EntityAgent.act(self, action_spec)
#     167 with self._control_lock:
#     168   self._set_phase(entity_component.Phase.PRE_ACT)
# --> 169   contexts = self._parallel_call_('pre_act', action_spec)
#     170   self._context_processor.pre_act(types.MappingProxyType(contexts))
#     171   action_attempt = self._act_component.get_action_attempt(
#     172       contexts, action_spec
#     173   )
#
# File ~\Documents\dev\concordia\concordia_orgin\concordia\concordia\agents\entity_agent.py:153, in EntityAgent._parallel_call_(self, method_name, executor, *args)
#     146 # 2. Create and execute tasks for each unique component instance once.
#     147 tasks_for_unique = {
#     148     str(id(component)): functools.partial(
#     149         getattr(component, method_name), *args
#     150     )
#     151     for component in unique_components
#     152 }
# --> 153 results_by_component_id = concurrency.run_tasks(
#     154     tasks_for_unique, executor=executor)
#     156 # 3. Construct the final results dictionary.
#     157 final_results: dict[str, str] = {}
#
# File ~\Documents\dev\concordia\concordia_orgin\concordia\concordia\utils\concurrency.py:139, in run_tasks(tasks, timeout, max_workers, executor)
#     112 def run_tasks(
#     113     tasks: Mapping[str, Callable[[], _T]],
#     114     *,
#    (...)    117     executor: futures.ThreadPoolExecutor | None = None,
#     118 ) -> Mapping[str, _T]:
#     119   """Runs the callables in parallel, blocks until first failure.
#     120
#     121   IMPORTANT: Passed callables must be threadsafe.
#    (...)    136     Exception: If any task raises an exception.
#     137   """
#     138   return {
# --> 139       key: future.result()
#     140       for key, future in _as_completed(
#     141           tasks, timeout=timeout, max_workers=max_workers, executor=executor
#     142       )
#     143   }
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File ~\Documents\dev\concordia\concordia_orgin\concordia\concordia\utils\concurrency.py:60, in _run_task(key, fn)
#      58 """Returns fn() and logs any error."""
#      59 try:
# ---> 60   return fn()
#      61 except:
#      62   logging.exception('Error in task %s', key)
#
# File ~\Documents\dev\concordia\concordia_orgin\concordia\concordia\components\game_master\next_game_master.py:281, in FormativeMemoriesInitializer.pre_act(self, action_spec)
#     273 tasks = {
#     274     player_name: functools.partial(
#     275         _process_player, player_name, memory, make_observation
#     276     )
#     277     for player_name in self._player_names
#     278 }
#     280 # Run entity actions concurrently
# --> 281 concurrency.run_tasks(tasks)
#     283 self._initialized = True
#     284 return self.get_entity().name
#
# File ~\Documents\dev\concordia\concordia_orgin\concordia\concordia\utils\concurrency.py:139, in run_tasks(tasks, timeout, max_workers, executor)
#     112 def run_tasks(
#     113     tasks: Mapping[str, Callable[[], _T]],
#     114     *,
#    (...)    117     executor: futures.ThreadPoolExecutor | None = None,
#     118 ) -> Mapping[str, _T]:
#     119   """Runs the callables in parallel, blocks until first failure.
#     120
#     121   IMPORTANT: Passed callables must be threadsafe.
#    (...)    136     Exception: If any task raises an exception.
#     137   """
#     138   return {
# --> 139       key: future.result()
#     140       for key, future in _as_completed(
#     141           tasks, timeout=timeout, max_workers=max_workers, executor=executor
#     142       )
#     143   }
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File ~\Documents\dev\concordia\concordia_orgin\concordia\concordia\utils\concurrency.py:60, in _run_task(key, fn)
#      58 """Returns fn() and logs any error."""
#      59 try:
# ---> 60   return fn()
#      61 except:
#      62   logging.exception('Error in task %s', key)
#
# File ~\Documents\dev\concordia\concordia_orgin\concordia\concordia\components\game_master\next_game_master.py:263, in FormativeMemoriesInitializer.pre_act.<locals>._process_player(player_name, memory, make_observation)
#     261 for shared_memory in self._shared_memories:
#     262   make_observation.add_to_queue(player_name, shared_memory)
# --> 263 episodes = self.generate_backstory_episodes(player_name)
#     264 for episode in episodes:
#     265   make_observation.add_to_queue(player_name, episode)
#
# File ~\Documents\dev\concordia\concordia_orgin\concordia\concordia\components\game_master\next_game_master.py:333, in FormativeMemoriesInitializer.generate_backstory_episodes(self, active_entity_name)
#     315 question = (
#     316     f'Write a life story for a {gender} character '
#     317     f'named {active_entity_name} who was born in {date_of_birth}.'
#     318 )
#     319 question += (
#     320     f'Begin the story when {active_entity_name} is very young and end it'
#     321     ' when they are quite old. The story should be no more than four'
#    (...)    331     f' with a profound understanding of {active_entity_name}.'
#     332 )
# --> 333 backstory = prompt.open_question(
#     334     question,
#     335     max_tokens=4500,
#     336     terminators=['\nQuestion', '-----'],
#     337 )
#     338 backstory = re.sub(r'\.\s', '.\n', backstory)
#     340 inner_prompt = interactive_document.InteractiveDocument(self._model)
#
# File ~\Documents\dev\concordia\concordia_orgin\concordia\concordia\document\interactive_document.py:176, in InteractiveDocument.open_question(self, question, forced_response, answer_prefix, answer_suffix, max_tokens, terminators, question_label, answer_label)
#     174 self._response(f'{answer_label}: {answer_prefix}')
#     175 if forced_response is None:
# --> 176   response = self._model.sample_text(
#     177       prompt=self._model_view.text(),
#     178       max_tokens=max_tokens,
#     179       terminators=terminators,
#     180   )
#     181 else:
#     182   response = forced_response
#
# File ~\Documents\dev\concordia\concordia_orgin\concordia\concordia\language_model\base_oai_compatible.py:76, in BaseOAICompatibleModel.sample_text(self, prompt, max_tokens, terminators, temperature, timeout, seed)
#      50 # The system prompt and few-shot examples from the original file are kept.
#      51 messages = [
#      52     {
#      53         'role': 'system',
#    (...)     73     {'role': 'user', 'content': prompt},
#      74 ]
# ---> 76 response = self._client.chat.completions.create(
#      77     model=self._model_name,
#      78     messages=messages,
#      79     temperature=temperature,
#      80     max_tokens=max_tokens,
#      81     timeout=timeout,
#      82     stop=terminators,
#      83     seed=seed,
#      84 )
#      86 if self._measurements is not None:
#      87   self._measurements.publish_datum(
#      88       self._channel,
#      89       {'raw_text_length': len(response.choices[0].message.content)},
#      90   )
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\openai\resources\chat\completions\completions.py:1087, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1044 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1045 def create(
#    1046     self,
#    (...)   1084     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1085 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1086     validate_response_format(response_format)
# -> 1087     return self._post(
#    1088         "/chat/completions",
#    1089         body=maybe_transform(
#    1090             {
#    1091                 "messages": messages,
#    1092                 "model": model,
#    1093                 "audio": audio,
#    1094                 "frequency_penalty": frequency_penalty,
#    1095                 "function_call": function_call,
#    1096                 "functions": functions,
#    1097                 "logit_bias": logit_bias,
#    1098                 "logprobs": logprobs,
#    1099                 "max_completion_tokens": max_completion_tokens,
#    1100                 "max_tokens": max_tokens,
#    1101                 "metadata": metadata,
#    1102                 "modalities": modalities,
#    1103                 "n": n,
#    1104                 "parallel_tool_calls": parallel_tool_calls,
#    1105                 "prediction": prediction,
#    1106                 "presence_penalty": presence_penalty,
#    1107                 "reasoning_effort": reasoning_effort,
#    1108                 "response_format": response_format,
#    1109                 "seed": seed,
#    1110                 "service_tier": service_tier,
#    1111                 "stop": stop,
#    1112                 "store": store,
#    1113                 "stream": stream,
#    1114                 "stream_options": stream_options,
#    1115                 "temperature": temperature,
#    1116                 "tool_choice": tool_choice,
#    1117                 "tools": tools,
#    1118                 "top_logprobs": top_logprobs,
#    1119                 "top_p": top_p,
#    1120                 "user": user,
#    1121                 "web_search_options": web_search_options,
#    1122             },
#    1123             completion_create_params.CompletionCreateParamsStreaming
#    1124             if stream
#    1125             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1126         ),
#    1127         options=make_request_options(
#    1128             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1129         ),
#    1130         cast_to=ChatCompletion,
#    1131         stream=stream or False,
#    1132         stream_cls=Stream[ChatCompletionChunk],
#    1133     )
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\openai\_base_client.py:1249, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1235 def post(
#    1236     self,
#    1237     path: str,
#    (...)   1244     stream_cls: type[_StreamT] | None = None,
#    1245 ) -> ResponseT | _StreamT:
#    1246     opts = FinalRequestOptions.construct(
#    1247         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1248     )
# -> 1249     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\openai\_base_client.py:990, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     987         continue
#     989     log.debug("Raising timeout error")
# --> 990     raise APITimeoutError(request=request) from err
#     991 except Exception as err:
#     992     log.debug("Encountered Exception", exc_info=True)
#
# APITimeoutError: Request timed out.
# ERROR:absl:Error in task Oliver Cromwell
# Traceback (most recent call last):
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_transports\default.py", line 101, in map_httpcore_exceptions
#     yield
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_transports\default.py", line 250, in handle_request
#     resp = self._pool.handle_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\connection_pool.py", line 256, in handle_request
#     raise exc from None
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\connection_pool.py", line 236, in handle_request
#     response = connection.handle_request(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\connection.py", line 103, in handle_request
#     return self._connection.handle_request(request)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\http11.py", line 136, in handle_request
#     raise exc
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\http11.py", line 106, in handle_request
#     ) = self._receive_response_headers(**kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\http11.py", line 177, in _receive_response_headers
#     event = self._receive_event(timeout=timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_sync\http11.py", line 217, in _receive_event
#     data = self._network_stream.read(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_backends\sync.py", line 126, in read
#     with map_exceptions(exc_map):
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\contextlib.py", line 158, in __exit__
#     self.gen.throw(value)
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpcore\_exceptions.py", line 14, in map_exceptions
#     raise to_exc(exc) from exc
# httpcore.ReadTimeout: timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\openai\_base_client.py", line 972, in request
#     response = self._client.send(
#                ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_client.py", line 914, in send
#     response = self._send_handling_auth(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_client.py", line 942, in _send_handling_auth
#     response = self._send_handling_redirects(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_client.py", line 979, in _send_handling_redirects
#     response = self._send_single_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_client.py", line 1014, in _send_single_request
#     response = transport.handle_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_transports\default.py", line 249, in handle_request
#     with map_httpcore_exceptions():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\contextlib.py", line 158, in __exit__
#     self.gen.throw(value)
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\httpx\_transports\default.py", line 118, in map_httpcore_exceptions
#     raise mapped_exc(message) from exc
# httpx.ReadTimeout: timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\tyler\Documents\dev\concordia\concordia_orgin\concordia\concordia\utils\concurrency.py", line 60, in _run_task
#     return fn()
#            ^^^^
#   File "C:\Users\tyler\Documents\dev\concordia\concordia_orgin\concordia\concordia\components\game_master\next_game_master.py", line 263, in _process_player
#     episodes = self.generate_backstory_episodes(player_name)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\tyler\Documents\dev\concordia\concordia_orgin\concordia\concordia\components\game_master\next_game_master.py", line 361, in generate_backstory_episodes
#     aggregated_result = prompt.open_question(
#                         ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\tyler\Documents\dev\concordia\concordia_orgin\concordia\concordia\document\interactive_document.py", line 176, in open_question
#     response = self._model.sample_text(
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\tyler\Documents\dev\concordia\concordia_orgin\concordia\concordia\language_model\base_oai_compatible.py", line 76, in sample_text
#     response = self._client.chat.completions.create(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\openai\_utils\_utils.py", line 287, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\openai\resources\chat\completions\completions.py", line 1087, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\openai\_base_client.py", line 1249, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\tyler\miniconda3\envs\a0\Lib\site-packages\openai\_base_client.py", line 990, in request
#     raise APITimeoutError(request=request) from err
# openai.APITimeoutError: Request timed out.

# %%
# @title Display the log
display.HTML(results_log)
